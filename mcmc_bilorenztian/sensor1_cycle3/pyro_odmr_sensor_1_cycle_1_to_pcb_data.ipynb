# %%
import torch
import pyro
import pyro.distributions as dist
from pyro.infer import MCMC, NUTS, HMC
from IPython.core.pylabtools import figsize
import numpy as np
import pandas as pd

from pathlib import Path
import glob
from matplotlib import pyplot as plt
from scipy.stats.mstats import mquantiles
from sklearn.preprocessing import MinMaxScaler
from pyro.infer.autoguide import init_to_value

# %% [markdown]
# # Parameter determination for function
# We specify a bi-Lorentzian model for the ODMR spectra where the mean values change is driven by a learned linear function that depends on temperature. In the first part, we learn the parameters of the linear "calibration" function that maps the peak center positions on to temperature. This learned model- referred to as the calibrated_model-  is then subsequently used to predict temperatures given spectra and associated uncertainty in the predicted value.

# %% [markdown]
# ## Set up function
# Here we import the data, define a bi-Lorentzian function and demonstrate the impact of different values of center 1 and center 2 (A and B, respectively) on the simulated spectra.

# %%
temps_ = ['25', '30', '35',
       '40', '45', '50', '45', '40', '35', '30', '25', '20']
temps = np.array(temps_, dtype=float)

temps = temps + 273.15  # Convert to Kelvin

temps = torch.tensor(temps).double()

temps_whole = temps.clone()

temps = temps[:6]

# %%
len(temps)
# Out:
# 6

# %%
## import data file
fpath = '../saved_data/cycle1'

df_= pd.read_csv(fpath, sep=',', header = 0); 
df= df_.iloc[0:, 1:-1]
df.drop(columns= ['25 C-lower power', '15', '10', '10.1', '-30', '-20'], inplace= True)
df.iloc[:, 2:].plot(legend= False)

# define and scale the frequency axis 
x_esr_ = df.frequency.values/1e9
y_esr = df.iloc[:, 1:7]
y_esr_ = df.iloc[:, 1:]
#scale x axis to 0-100
sc = MinMaxScaler(feature_range=(0, 100))
x_esr = sc.fit_transform(x_esr_.reshape(-1, 1)).flatten()

torch.set_default_dtype(torch.float64)

# %%
df.shape
print(y_esr.columns)
print(temps)
# Out:
# Index(['25up', '30up', '35up', '40down', '45down', '50'], dtype='object')
# tensor([298.1500, 303.1500, 308.1500, 313.1500, 318.1500, 323.1500])

# %%
# plot baseline subtracted  y data
y_esr = y_esr.apply(lambda x: x - x[:10].mean())#+0.01
y_esr = -1*y_esr
y_esr = y_esr.apply(lambda x: x/x.max())
plt.plot(x_esr, y_esr);
#plt.xlim(40, 80)

# %%
y_esr_ = y_esr_.apply(lambda x: x - x[:10].mean())#+0.01
y_esr_ = -1*y_esr_
y_esr_ = y_esr_.apply(lambda x: x/x.max())
plt.plot(x_esr, y_esr_);

# %%
#numpy version of function
def F_np(x_in, Amp, alpha, beta, T):
    # Reshape A, B, Amp, G1, G2 for broadcasting with x_in
    alpha = alpha[None, :]
    Amp_reshaped = Amp[None, :]
    T_reshaped = T[None, :]
    beta = beta[None, :]
    A_reshaped = (T_reshaped*alpha) + beta # Shape (1, num_samples)
    X_reshaped = 8.420054307219287
    B_reshaped = A_reshaped + X_reshaped
     # Shape (1, num_samples)
    G1_reshaped = 8.020510711744828 # New: Reshape gamma1
    G2_reshaped = 8.020510711744828 # New: Reshape gamma2
    
    x_in_reshaped = x_in[:, None] # Shape (num_x_points, 1)

    F = (Amp_reshaped) * (0.5 * G1_reshaped) / ((x_in_reshaped - A_reshaped)**2 + (0.5 * G1_reshaped)**2) \
        + (Amp_reshaped) * (0.5 * G2_reshaped) / ((x_in_reshaped - B_reshaped)**2 + (0.5 * G2_reshaped)**2)
    return F


# A function to sample values of A and B and plot resulting function.
def F_samples():
    amp = pyro.sample("Amp", dist.Normal(0.95, 0.25))
    alpha = pyro.sample("alpha", dist.Normal(-71, 7.0)).double() /1000
    beta = pyro.sample("beta", dist.Normal(42., 10.0)) # Sample gamma1
    T_ = torch.tensor(273.15).double()
    T = T_ * np.ones_like(alpha) 
    A =  T*alpha + beta
    B =  A + 8.420054307219287
    gamma1 =  pyro.sample("gamma1", dist.Normal(8.02, 1.0)).double()
    gamma2 = gamma1
    # Use the sampled gamma values in the function
    f_sim = lambda xi: (amp) *(0.5*gamma1)/((xi-A)**2 + (0.5*gamma1)**2) + (amp) *(0.5*gamma2)/((xi-B)**2 + (0.5*gamma2)**2)
    plt.plot(x_esr, f_sim(x_esr))
    # Update title to show sampled gamma values
    plt.title('A:' + str(A.numpy()) + ' B:' + str(B.numpy()) + ' G1:' + str(gamma1.numpy()) + ' G2:' + str(gamma2.numpy()))

# %% [markdown]
# ## Define data we will start with and plot.

# %%
# this will be the data we'll start with, shown as red circles
def dataslicer(x, y, col1 =0 ,col2=1):
    x_tensor = torch.tensor(x).double()
    # squeeze the selected column to produce a 1-D tensor (N,) instead of (N,1)
    y_vals = y.iloc[:, col1:col2].values.squeeze()
    y_tensor = torch.tensor(y_vals).double()
    return x_tensor, y_tensor

# %% [markdown]
# ## Set up and run Bayesian inference

# %%
# define the model
# Here we assume that we know the noise variance in the data = 0.1,
# though this can be set to another parameter to learn.

x_obs, y_obs = dataslicer(x_esr, y_esr, col1=0, col2=1)
T_ = 273.15 + 25.0  # Example temperature in Kelvin

data_ = (T_, (x_obs.clone().detach().double(), y_obs.clone().detach().double()))

def model(data_):
    T, data, = data_[0], data_[1]
    alpha = pyro.sample("alpha", dist.Normal(-0.077, 0.01)).double() 
    beta = pyro.sample("beta", dist.Normal(70., 10.0)) # Sample gamma1
    var = pyro.sample("var", dist.HalfNormal(scale=0.1)).double()
    gamma1 =  pyro.sample("gamma1", dist.Normal(8.02, 1.0)).double()
    A =  T*alpha + beta
    B =  A + 8.420054307219287
    #gamma1 =  8.020510711744828 
    gamma2 = gamma1#pyro.sample("gamma2", dist.Normal(8.02, 1.0)).double()
    amp =  pyro.sample("amp", dist.Normal(3., 0.25 )).double()
    F =  (amp) * (0.5 * gamma1) / ((data[0] - A)**2 + (0.5 * gamma1)**2) \
        + (amp) * (0.5 * gamma2) / ((data[0] - B)**2 + (0.5 * gamma2)**2)
    
    # ensure F is a 1-D mean vector matching y_obs
    F = F.squeeze()

    #with pyro.plate("data", data[0].size(0)):
    pyro.sample("obs", dist.MultivariateNormal(F, var * torch.eye(data[1].shape[0]).double()), obs=data[1])

# %%
plt.plot(x_obs, y_obs, 'o')
#plt.xlim(40, 70)

# %%
temps = torch.tensor(temps).double()
# Out:
# C:\Users\zahmed\AppData\Local\Temp\1\ipykernel_21584\2747252934.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   temps = torch.tensor(temps).double()

# %%
# solve for the posterior using MCMC
# Use the observed x positions and y values as the data passed to the model


init_vals = {
    "alpha": torch.tensor(-0.077),
    "beta": torch.tensor(71.0),
    "gamma1": torch.tensor(7.8),
    "amp": torch.tensor(3.0),
    "var": torch.tensor(0.05),}


kernel = NUTS(model, jit_compile=True, init_strategy=init_to_value(values=init_vals), max_tree_depth=6, ignore_jit_warnings=True)
posterior = MCMC(kernel, num_samples=1000, warmup_steps=200, num_chains=1)
posterior.run((data_))
# Out:
# Sample: 100%|██████████| 1200/1200 [03:42,  5.40it/s, step size=4.10e-02, acc. prob=0.924]

# %%
hmc_samples = {k: v.detach().cpu().numpy() for k, v in posterior.get_samples().items()}
alpha = hmc_samples['alpha']
beta = hmc_samples['beta']
Amp = hmc_samples['amp'] # Get posterior samples for amp
var = hmc_samples['var'] # Get posterior samples for var
T = T_ * np.ones_like(alpha)  # Create T array matching alpha shape
F = F_np(x_esr, Amp, alpha, beta, T)
qs = mquantiles(F.T, [0.025, 0.975], axis=0)
F_mean = F.mean(axis = 1)

print('#################')
plt.fill_between(x_esr.flatten(), qs[0], qs[1], alpha=0.7, color="#7A68A6");
plt.plot(x_esr, F_mean)
plt.plot(x_obs, y_obs, 'ro'); # plotting the data for this slice
plt.xlabel('frequency axis')
plt.title('Posterior distribution for the function given distributions for all parameters');plt.show()
pyro.clear_param_store()
print('#################')
# Out:
# #################
# #################

# %%
print(f'alpha = {np.array(alpha).mean():.4f}')
print(f'alpha error = {np.array(alpha).var():.6f}')
print(f'beta = {np.array(beta).mean():.4f}')
print(f'beta error = {np.array(beta).var():.6f}')
print(f'gamma1 = {np.array(hmc_samples["gamma1"]).mean():.4f}')
print(f'gamma1 error = {np.array(hmc_samples["gamma1"]).var():.6f}')
print(f'amp = {np.array(hmc_samples["amp"]).mean():.4f}')
print(f'amp error = {np.array(hmc_samples["amp"]).var():.6f}')
# Out:
# alpha = -0.0802
# alpha error = 0.000107
# beta = 72.6511
# beta error = 9.534967
# gamma1 = 8.0739
# gamma1 error = 0.065327
# amp = 3.1787
# amp error = 0.002595

# %% [markdown]
# ## Get results and plot

# %%
idx = []
error_alpha = []
error_beta = []
alpha_, beta_, amp_ = [], [], []
gamma1_vals = []
beta_var, alpha_var, gamma1_var, amp_var = [], [], [], []

# init vals for MCMC

init_vals = {
    "alpha": torch.tensor(-0.077),
    "beta": torch.tensor(71.0),
    "gamma1": torch.tensor(7.8),
    "amp": torch.tensor(3.0),
    "var": torch.tensor(0.05),}


for j in range(0, y_esr.shape[1]):
  print(j)
  print(init_vals)
  x_obs_j, y_obs_j = dataslicer(x_esr, y_esr, col1=j, col2=j+1)
  temps_j = temps[j]
  data_j_ = (temps_j, (x_obs_j[0:].clone().detach().double(), y_obs_j[0:].clone().detach().double()))
  kernel = NUTS(model, jit_compile=True, init_strategy=init_to_value(values=init_vals), ignore_jit_warnings=True, max_tree_depth=6)
  posterior = MCMC(kernel, num_samples=2000, warmup_steps=200, num_chains=1)
  posterior.run(data_j_)
  hmc_samples = {k: v.detach().cpu().numpy() for k, v in posterior.get_samples().items()}
  alpha = hmc_samples['alpha']
  beta = hmc_samples['beta']
  Amp = hmc_samples['amp'] # Get posterior samples for amp
  var = hmc_samples['var'] # Get posterior samples for var
  T = temps_j.item() * np.ones_like(alpha)  # Create T array matching alpha shape
  gamma1_ = hmc_samples['gamma1'] # Get posterior samples for gamma1
  gamma2_ = hmc_samples['gamma1'] # Get posterior samples for gamma2 (since gamma2 = gamma1 in the model)
  var = hmc_samples['var'] # Get posterior samples for var
  F = F_np(x_esr, Amp, alpha, beta, T)
  qs = mquantiles(F.T, [0.025, 0.975], axis=0)
  F_mean = F.mean(axis = 1)
  idx.append(j)
  amp_.append(Amp.mean())  
  alpha_.append(alpha.mean())
  beta_.append(beta.mean())
  gamma1_vals.append(gamma1_.mean())
  alpha_var.append(alpha.var())
  beta_var.append(beta.var())
  gamma1_var.append(gamma1_.var())
  amp_var.append(Amp.var())
  print('#################')
  plt.fill_between(x_esr.flatten(), qs[0], qs[1], alpha=0.7, color="#7A68A6")
  plt.plot(x_esr, F_mean)
  plt.plot(x_obs_j, y_obs_j, 'ro'); # plotting the data for this slice
  plt.xlabel('frequency axis')
  plt.title('Posterior distribution for the function given distributions for all parameters');plt.show()
  #pyro.clear_param_store()
  init_vals = {
      "alpha": torch.tensor(alpha.mean()),
      "beta": torch.tensor(beta.mean()),
      "gamma1": torch.tensor(gamma1_.mean()),
      "amp": torch.tensor(Amp.mean()),
      "var": torch.tensor(var.mean()),}    
  print('#################')
# Out:
# 0
# {'alpha': tensor(-0.0770), 'beta': tensor(71.), 'gamma1': tensor(7.8000), 'amp': tensor(3.), 'var': tensor(0.0500)}
# Sample: 100%|██████████| 2200/2200 [07:11,  5.10it/s, step size=3.63e-02, acc. prob=0.946]
# #################
# #################
# 1
# {'alpha': tensor(-0.0765), 'beta': tensor(71.5525), 'gamma1': tensor(8.0126), 'amp': tensor(3.1688), 'var': tensor(0.0022)}
# Sample: 100%|██████████| 2200/2200 [07:49,  4.68it/s, step size=3.53e-02, acc. prob=0.951]
# #################
# #################
# 2
# {'alpha': tensor(-0.0785), 'beta': tensor(72.1473), 'gamma1': tensor(7.6839), 'amp': tensor(3.1495), 'var': tensor(0.0025)}
# Sample: 100%|██████████| 2200/2200 [07:51,  4.67it/s, step size=2.97e-02, acc. prob=0.950]
# #################
# #################
# 3
# {'alpha': tensor(-0.0784), 'beta': tensor(71.9961), 'gamma1': tensor(8.1291), 'amp': tensor(3.1649), 'var': tensor(0.0017)}
# Sample: 100%|██████████| 2200/2200 [08:00,  4.58it/s, step size=3.03e-02, acc. prob=0.945]
# #################
# #################
# 4
# {'alpha': tensor(-0.0786), 'beta': tensor(72.0950), 'gamma1': tensor(8.0670), 'amp': tensor(3.1619), 'var': tensor(0.0017)}
# Sample: 100%|██████████| 2200/2200 [07:49,  4.69it/s, step size=3.66e-02, acc. prob=0.931]
# #################
# #################
# 5
# {'alpha': tensor(-0.0763), 'beta': tensor(71.5642), 'gamma1': tensor(8.3887), 'amp': tensor(3.1744), 'var': tensor(0.0019)}
# Sample: 100%|██████████| 2200/2200 [07:21,  4.98it/s, step size=3.06e-02, acc. prob=0.947]
# #################
# #################

# %%
print(f'alpha = {np.array(alpha_).mean():.4f}')
print(f'alpha error = {np.array(alpha_var).mean():.6f}')

print(f'beta = {np.array(beta_).mean():.4f}')
print(f'beta error = {np.array(beta_var).mean():.6f}')


print(f'gamma1 = {np.array(gamma1_).mean():.4f}')
print(f'gamma1 error = {np.array(gamma1_var).mean():.6f}')
# Out:
# alpha = -0.0777
# alpha error = 0.000016
# beta = 71.8865
# beta error = 1.473624
# gamma1 = 8.1238
# gamma1 error = 0.065042

# %%
### define the calibrated model

def calibrated_model(data_):
    data = data_
    alpha = torch.tensor(np.array(alpha_).mean()).double()
    beta = torch.tensor(np.array(beta_).mean()).double()
    var = pyro.sample("var", dist.HalfNormal(scale=0.1)).double()
    gamma1 =  pyro.sample("gamma1", dist.Normal(np.array(gamma1_).mean(), 1.)).double()
    T = pyro.sample("T", dist.Uniform(242, 343)).double()
    A =  T*alpha + beta
    B =  A + 8.420054307219287
    gamma2 = gamma1#pyro.sample("gamma2", dist.Normal(8.02, 1.0)).double()
    amp =  pyro.sample("amp", dist.Normal(3.25, 0.25 )).double()
    F =  (amp) * (0.5 * gamma1) / ((data[0] - A)**2 + (0.5 * gamma1)**2) \
        + (amp) * (0.5 * gamma2) / ((data[0] - B)**2 + (0.5 * gamma2)**2)
    
    # ensure F is a 1-D mean vector matching y_obs
    F = F.squeeze()

    #with pyro.plate("data", data[0].size(0)):
    pyro.sample("obs", dist.MultivariateNormal(F, var * torch.eye(data[1].shape[0]).double()), obs=data[1])

# %%
#numpy version of function
def F_np_calibrated(x_in, Amp, gamma, T):
    # Reshape A, B, Amp, G1, G2 for broadcasting with x_in
    alpha = np.array(alpha_).mean()
    Amp_reshaped = Amp[None, :]
    T_reshaped = T[None, :]
    beta = np.array(beta_).mean()
    A_reshaped = (T_reshaped*alpha) + beta # Shape (1, num_samples)
    X_reshaped = 8.420054307219287
    B_reshaped = A_reshaped + X_reshaped
     # Shape (1, num_samples)
    G1_reshaped = gamma[None, :] # New: Reshape gamma1
    G2_reshaped = gamma[None, :] # New: Reshape gamma2

    x_in_reshaped = x_in[:, None] # Shape (num_x_points, 1)

    F = (Amp_reshaped) * (0.5 * G1_reshaped) / ((x_in_reshaped - A_reshaped)**2 + (0.5 * G1_reshaped)**2) \
        + (Amp_reshaped) * (0.5 * G2_reshaped) / ((x_in_reshaped - B_reshaped)**2 + (0.5 * G2_reshaped)**2)
    return F


# A function to sample values of A and B and plot resulting function.
def F_calibrated_samples():
    alpha = torch.tensor(np.array(alpha_).mean()).double()
    beta = torch.tensor(np.array(beta_).mean()).double()
    var = pyro.sample("var", dist.HalfNormal(scale=0.1)).double()
    gamma1 =  pyro.sample("gamma1", dist.Normal(8.02, 1.0)).double()
    T = pyro.sample("T", dist.Uniform(242, 343)).double() * torch.ones_like(alpha)
    A =  T*alpha + beta
    B =  A + 8.420054307219287
    gamma2 = gamma1#pyro.sample("gamma2", dist.Normal(8.02, 1.0)).double()
    amp =  pyro.sample("amp", dist.Normal(1.25, 0.25 )).double()
    
    f_sim = lambda xi: (amp) *(0.5*gamma1)/((xi-A)**2 + (0.5*gamma1)**2) + (amp) *(0.5*gamma2)/((xi-B)**2 + (0.5*gamma2)**2)
    plt.plot(x_esr, f_sim(x_esr))
    # Update title to show sampled gamma values
    plt.title('A:' + str(A.numpy()) + ' B:' + str(B.numpy()) + ' G1:' + str(gamma1.numpy()) + ' G2:' + str(gamma2.numpy()))

# %%
y_esr_.iloc[:, 6:]
# Out:
#           45        40        35        30        25        20
# 0   0.008034  0.012119  0.010351  0.013599  0.028153  0.000391
# 1   0.009279 -0.017508  0.051372 -0.003267  0.045319 -0.016045
# 2   0.013677  0.021419 -0.018529  0.040465  0.007188  0.007520
# 3  -0.001087  0.048420 -0.031688 -0.003929  0.011347 -0.018326
# 4  -0.026094 -0.006723  0.023181 -0.016757  0.027110  0.042432
# ..       ...       ...       ...       ...       ...       ...
# 95  0.008834 -0.019738 -0.043713 -0.008166  0.022111 -0.064051
# 96 -0.056837 -0.009815 -0.021166 -0.028829 -0.026994 -0.058941
# 97 -0.059692 -0.022073 -0.013873 -0.006787 -0.021621 -0.017266
# 98  0.033100 -0.040302 -0.016432 -0.019551 -0.038921 -0.055053
# 99 -0.003825 -0.027492 -0.020883 -0.024088  0.008174 -0.066772
#
# [100 rows x 6 columns]

# %%
idx = []
temp_, amp_ = [], []
gamma1_vals = []
gamma1_var, amp_var = [], []
temp_var = []
temp_ci_high, temp_ci_low = [], []



# init vals for MCMC

init_vals = {
    "T": torch.tensor(300.),
    "gamma1": torch.tensor(7.8),
    "amp": torch.tensor(3.0),
    "var": torch.tensor(0.05),}


for j in range(0, y_esr_.shape[1]):
  print(j)
  x_obs_j, y_obs_j = dataslicer(x_esr, y_esr_, col1=j, col2=j+1)
  temps_j = temps_whole[j]
  data_j = (x_obs_j[:].clone().detach().double(), y_obs_j[:].clone().detach().double())
  kernel = NUTS(calibrated_model, jit_compile=True, init_strategy=init_to_value(values=init_vals), ignore_jit_warnings=True, max_tree_depth=6)
  posterior = MCMC(kernel, num_samples=2000, warmup_steps=200, num_chains=1)
  posterior.run(data_j)
  hmc_samples = {k: v.detach().cpu().numpy() for k, v in posterior.get_samples().items()}
  T = hmc_samples['T']
  Amp = hmc_samples['amp'] # Get posterior samples for amp
  var = hmc_samples['var'] # Get posterior samples for var
  gamma1_ = hmc_samples['gamma1'] # Get posterior samples for gamma1
  var = hmc_samples['var'] # Get posterior samples for var
  F = F_np_calibrated(x_esr, Amp, gamma1_, T)
  qs = mquantiles(F.T, [0.025, 0.975], axis=0)
  F_mean = F.mean(axis = 1)
  idx.append(j)
  amp_.append(Amp.mean())  
  gamma1_vals.append(gamma1_.mean())
  temp_.append(T.mean())
  temp_var.append(T.var())
  gamma1_var.append(gamma1_.var())
  amp_var.append(Amp.var())
  T_ci = np.quantile(T, [0.025, 0.975])
  temp_ci_low.append(T_ci[0])
  temp_ci_high.append(T_ci[1])
  print('#################')
  print(f'experimental temperature: {temps_j.item():.2f} K, inferred temperature: {T.mean():.2f} K')
  plt.fill_between(x_esr.flatten(), qs[0], qs[1], alpha=0.7, color="#7A68A6");
  plt.plot(x_esr, F_mean)
  plt.plot(x_obs_j, y_obs_j, 'ro'); # plotting the data for this slice
  plt.xlabel('frequency axis')
  plt.title('Posterior distribution for the function given distributions for all parameters');plt.show()  
  print('#################')
# Out:
# 0
# Sample: 100%|██████████| 2200/2200 [00:54, 40.04it/s, step size=6.02e-01, acc. prob=0.923]
# #################
# experimental temperature: 298.15 K, inferred temperature: 297.77 K
# #################
# 1
# Sample: 100%|██████████| 2200/2200 [00:53, 41.06it/s, step size=5.28e-01, acc. prob=0.925]
# #################
# experimental temperature: 303.15 K, inferred temperature: 303.06 K
# #################
# 2
# Sample: 100%|██████████| 2200/2200 [00:53, 41.34it/s, step size=5.52e-01, acc. prob=0.924]
# #################
# experimental temperature: 308.15 K, inferred temperature: 309.47 K
# #################
# 3
# Sample: 100%|██████████| 2200/2200 [00:53, 41.00it/s, step size=6.42e-01, acc. prob=0.927]
# #################
# experimental temperature: 313.15 K, inferred temperature: 313.99 K
# #################
# 4
# Sample: 100%|██████████| 2200/2200 [00:50, 43.33it/s, step size=5.74e-01, acc. prob=0.922]
# #################
# experimental temperature: 318.15 K, inferred temperature: 316.41 K
# #################
# 5
# Sample: 100%|██████████| 2200/2200 [00:57, 38.45it/s, step size=5.20e-01, acc. prob=0.925]
# #################
# experimental temperature: 323.15 K, inferred temperature: 323.38 K
# #################
# 6
# Sample: 100%|██████████| 2200/2200 [00:52, 42.13it/s, step size=6.56e-01, acc. prob=0.917]
# #################
# experimental temperature: 318.15 K, inferred temperature: 317.95 K
# #################
# 7
# Sample: 100%|██████████| 2200/2200 [00:49, 44.52it/s, step size=7.60e-01, acc. prob=0.903]
# #################
# experimental temperature: 313.15 K, inferred temperature: 312.57 K
# #################
# 8
# Sample: 100%|██████████| 2200/2200 [00:51, 43.13it/s, step size=6.26e-01, acc. prob=0.900]
# #################
# experimental temperature: 308.15 K, inferred temperature: 308.08 K
# #################
# 9
# Sample: 100%|██████████| 2200/2200 [00:54, 40.51it/s, step size=5.69e-01, acc. prob=0.917]
# #################
# experimental temperature: 303.15 K, inferred temperature: 301.46 K
# #################
# 10
# Sample: 100%|██████████| 2200/2200 [00:51, 42.51it/s, step size=6.17e-01, acc. prob=0.923]
# #################
# experimental temperature: 298.15 K, inferred temperature: 297.11 K
# #################
# 11
# Sample: 100%|██████████| 2200/2200 [01:09, 31.49it/s, step size=4.29e-01, acc. prob=0.953]
# #################
# experimental temperature: 293.15 K, inferred temperature: 292.21 K
# #################

# %%
print(f'amp = {np.array(amp_).mean():.4f}')
print(f'amp error = {np.array(amp_var).mean():.6f}')

print(f'gamma1 = {np.array(gamma1_vals).mean():.4f}')
print(f'gamma1 error = {np.array(gamma1_var).mean():.6f}')

print(f'Temperature = {np.array(temp_).mean():.2f} K')
print(f'Temperature error = {np.array(temp_var).mean():.6f}')
# Out:
# amp = 3.1765
# amp error = 0.002932
# gamma1 = 7.9984
# gamma1 error = 0.072303
# Temperature = 307.79 K
# Temperature error = 1.983073

# %%
temperature = np.asarray(temp_)
plt.plot(temperature, 'o-')
plt.plot(np.asarray(temps[:]), 'ro--')
plt.plot(np.asarray(temps_whole[:]), 'rx--')

plt.legend([ 'Predicted Temperature (Training)', 'Measured Temperature',])

# %%
# plt.plot(np.array(temps[1:]), temperature, 'r--')
plt.plot(np.asarray(temps), temperature[:6], 'bo')
plt.xlabel('Experimental Temperature (K)')
plt.ylabel('Inferred Temperature (K)')
import seaborn as sns
sns.regplot(x = np.asarray(temps_whole[:6]), y = temperature[:6])
# Out:
# <Axes: xlabel='Experimental Temperature (K)', ylabel='Inferred Temperature (K)'>

# %%
np.sqrt(np.mean((np.asarray(temps_whole) -  temperature)**2))
# Out:
# np.float64(0.9518171584747745)

# %%
np.sqrt(np.mean((np.asarray(temps_whole)[6:] -  temperature[6:])**2))
# Out:
# np.float64(0.9304873403622894)

# %%
plt.plot(np.asarray(temperature[:6]), np.asarray(temps_whole[:6]), 'bo')
plt.plot(np.asarray(temperature[6:]), np.asarray(temps_whole[6:]), 'rx')
plt.fill_between(temps_whole[6:], temp_ci_low[6:], temp_ci_high[6:], alpha=0.3, color='C0', label='k=1')
plt.xlabel('Experimental Temperature (K)')
plt.ylabel('Inferred Temperature (K)')
# Out:
# Text(0, 0.5, 'Inferred Temperature (K)')

# %%
# this function captures the temperature uncertainty
# we start by specifying a simple linear function for temperature

np.mean(temp_var)
# Out:
# np.float64(1.9830734126661769)

# %%
np.array(temp_ci_high) - np.array(temp_ci_low)
# Out:
# array([5.68157988, 5.92298829, 4.94478916, 4.61393017, 5.22981319,
#        5.44189466, 6.08760171, 5.37370931, 5.76749938, 5.3021926 ,
#        5.12250283, 6.39417247])

# %% [markdown]
# #### transfer learned model from sensor 1 cycle 1/ramp up to PCB data set

# %%
fpath_pcb = '../saved_data/pcb_microdiamond_cycles_1_and_2'

df_pcb = pd.read_csv(fpath_pcb, header = 0)


x_esr = df_pcb.iloc[:, 1]
y_esr_new = df_pcb.iloc[:, 2:]

sc = MinMaxScaler(feature_range=(0, 100))
x_esr_new = sc.fit_transform(x_esr_.reshape(-1, 1)).flatten()


plt.plot(x_esr_new, y_esr_new);plt.show()

# define and scale the frequency axis 
y_esr_new = y_esr_new.apply(lambda x: x - x[:10].mean())#+0.01
y_esr_new = -1*y_esr_new
y_esr_new = y_esr_new.apply(lambda x: x/x.max())
plt.plot(x_esr_new, y_esr_new);

# %%
temps_ = df_pcb.columns
measured_temp = np.array([25, 30, 35, 40, 45, 45.1, 40.1,
       35.1, 30.1, 25.1, 25.2, 30.2, 35.2, 40.2, 45.2,
       40.1, 35.1, 30.1, 25.1])

# %%
idx = []
temp_, amp_ = [], []
gamma1_vals = []
gamma1_var, amp_var = [], []
temp_var = []
temp_ci_high, temp_ci_low = [], []



# init vals for MCMC

init_vals = {
    "T": torch.tensor(300.),
    "gamma1": torch.tensor(7.8),
    "amp": torch.tensor(3.0),
    "var": torch.tensor(0.05),}


for j in range(0, 1 ): #
  print(j)
  x_obs_j, y_obs_j = dataslicer(x_esr_new, y_esr_new, col1=j, col2=j+1)
  # plt.plot(x_obs_j, y_obs_j, 'o')
  temps_j = measured_temp[j]
  data_j = (x_obs_j.clone().detach().double(), y_obs_j.clone().detach().double())
  kernel = NUTS(calibrated_model, jit_compile=True, init_strategy=init_to_value(values=init_vals), ignore_jit_warnings=True, max_tree_depth=9)
  posterior = MCMC(kernel, num_samples=2000, warmup_steps=200, num_chains=1)
  posterior.run(data_j)
  hmc_samples = {k: v.detach().cpu().numpy() for k, v in posterior.get_samples().items()}
  T = hmc_samples['T']
  Amp = hmc_samples['amp'] # Get posterior samples for amp
  var = hmc_samples['var'] # Get posterior samples for var
  gamma1_ = hmc_samples['gamma1'] # Get posterior samples for gamma1
  var = hmc_samples['var'] # Get posterior samples for var
  F = F_np_calibrated(x_esr_new.values.flatten(), Amp, gamma1_, T)
  qs = mquantiles(F.T, [0.025, 0.975], axis=0)
  F_mean = F.mean(axis = 1)
  idx.append(j)
  amp_.append(Amp.mean())  
  gamma1_vals.append(gamma1_.mean())
  temp_.append(T.mean())
  temp_var.append(T.var())
  gamma1_var.append(gamma1_.var())
  amp_var.append(Amp.var())
  T_ci = np.quantile(T, [0.025, 0.975])
  temp_ci_low.append(T_ci[0])
  temp_ci_high.append(T_ci[1])
  print('#################')
  print(f'experimental temperature: {temps_j.item():.2f} K, inferred temperature: {T.mean():.2f} K')
  plt.fill_between(x_esr_new.values.flatten(), qs[0], qs[1], alpha=0.7, color="#7A68A6");
  plt.plot(x_esr_new, F_mean)
  plt.plot(x_obs_j, y_obs_j, 'ro'); # plotting the data for this slice
  plt.xlabel('frequency axis')
  plt.title('Posterior distribution for the function given distributions for all parameters');plt.show()  
  print('#################')

# %% [markdown]
# #re-train model

# %%
idx = []
error_alpha = []
error_beta = []
alpha_, beta_, amp_ = [], [], []
gamma1_vals = []
beta_var, alpha_var, gamma1_var, amp_var = [], [], [], []

# init vals for MCMC

init_vals = {
    "alpha": torch.tensor(-0.077),
    "beta": torch.tensor(71.0),
    "gamma1": torch.tensor(7.8),
    "amp": torch.tensor(3.0),
    "var": torch.tensor(0.05),}


for j in range(0, 6):
  print(j)
  print(init_vals)
  x_obs_j, y_obs_j = dataslicer(x_esr, y_esr, col1=j, col2=j+1)
  temps_j = measured_temp[j]
  data_j_ = (temps_j, (x_obs_j[0:].clone().detach().double(), y_obs_j[0:].clone().detach().double()))
  kernel = NUTS(model, jit_compile=True, init_strategy=init_to_value(values=init_vals), ignore_jit_warnings=True, max_tree_depth=6)
  posterior = MCMC(kernel, num_samples=2000, warmup_steps=200, num_chains=1)
  posterior.run(data_j_)
  hmc_samples = {k: v.detach().cpu().numpy() for k, v in posterior.get_samples().items()}
  alpha = hmc_samples['alpha']
  beta = hmc_samples['beta']
  Amp = hmc_samples['amp'] # Get posterior samples for amp
  var = hmc_samples['var'] # Get posterior samples for var
  T = temps_j.item() * np.ones_like(alpha)  # Create T array matching alpha shape
  gamma1_ = hmc_samples['gamma1'] # Get posterior samples for gamma1
  gamma2_ = hmc_samples['gamma1'] # Get posterior samples for gamma2 (since gamma2 = gamma1 in the model)
  var = hmc_samples['var'] # Get posterior samples for var
  F = F_np(x_esr, Amp, alpha, beta, T)
  qs = mquantiles(F.T, [0.025, 0.975], axis=0)
  F_mean = F.mean(axis = 1)
  idx.append(j)
  amp_.append(Amp.mean())  
  alpha_.append(alpha.mean())
  beta_.append(beta.mean())
  gamma1_vals.append(gamma1_.mean())
  alpha_var.append(alpha.var())
  beta_var.append(beta.var())
  gamma1_var.append(gamma1_.var())
  amp_var.append(Amp.var())
  print('#################')
  plt.fill_between(x_esr.flatten(), qs[0], qs[1], alpha=0.7, color="#7A68A6")
  plt.plot(x_esr, F_mean)
  plt.plot(x_obs_j, y_obs_j, 'ro'); # plotting the data for this slice
  plt.xlabel('frequency axis')
  plt.title('Posterior distribution for the function given distributions for all parameters');plt.show()
  #pyro.clear_param_store()
  init_vals = {
      "alpha": torch.tensor(alpha.mean()),
      "beta": torch.tensor(beta.mean()),
      "gamma1": torch.tensor(gamma1_.mean()),
      "amp": torch.tensor(Amp.mean()),
      "var": torch.tensor(var.mean()),}    
  print('#################')
# Out:
# 0
# {'alpha': tensor(-0.0770), 'beta': tensor(71.), 'gamma1': tensor(7.8000), 'amp': tensor(3.), 'var': tensor(0.0500)}
# Sample: 100%|██████████| 2200/2200 [02:03, 17.85it/s, step size=2.52e-01, acc. prob=0.921]
# #################
# #################
# 1
# {'alpha': tensor(-0.0776), 'beta': tensor(50.6849), 'gamma1': tensor(8.0839), 'amp': tensor(3.1795), 'var': tensor(0.0022)}
# Sample: 100%|██████████| 2200/2200 [02:19, 15.74it/s, step size=2.79e-01, acc. prob=0.903]
# #################
# #################
# 2
# {'alpha': tensor(-0.0777), 'beta': tensor(50.6759), 'gamma1': tensor(7.7639), 'amp': tensor(3.1593), 'var': tensor(0.0026)}
# Sample: 100%|██████████| 2200/2200 [02:58, 12.30it/s, step size=1.81e-01, acc. prob=0.948]
# #################
# #################
# 3
# {'alpha': tensor(-0.0773), 'beta': tensor(50.5466), 'gamma1': tensor(8.0478), 'amp': tensor(3.1511), 'var': tensor(0.0017)}
# Sample: 100%|██████████| 2200/2200 [03:02, 12.02it/s, step size=1.54e-01, acc. prob=0.939]
# #################
# #################
# 4
# {'alpha': tensor(-0.0784), 'beta': tensor(50.6182), 'gamma1': tensor(7.9089), 'amp': tensor(3.1401), 'var': tensor(0.0017)}
# Sample: 100%|██████████| 2200/2200 [03:18, 11.07it/s, step size=1.56e-01, acc. prob=0.937]
# #################
# #################
# 5
# {'alpha': tensor(-0.0779), 'beta': tensor(50.8121), 'gamma1': tensor(8.4402), 'amp': tensor(3.1813), 'var': tensor(0.0019)}
# Sample: 100%|██████████| 2200/2200 [03:48,  9.63it/s, step size=1.09e-01, acc. prob=0.948]
# #################
# #################

# %%
idx = []
temp_, amp_ = [], []
gamma1_vals = []
gamma1_var, amp_var = [], []
temp_var = []
temp_ci_high, temp_ci_low = [], []



# init vals for MCMC

init_vals = {
    "T": torch.tensor(300.),
    "gamma1": torch.tensor(7.8),
    "amp": torch.tensor(3.0),
    "var": torch.tensor(0.05),}


for j in range(0, y_esr_new.shape[1] ): #
  print(j)
  x_obs_j, y_obs_j = dataslicer(x_esr_new, y_esr_new, col1=j, col2=j+1)
  # plt.plot(x_obs_j, y_obs_j, 'o')
  temps_j = measured_temp[j]
  data_j = (x_obs_j.clone().detach().double(), y_obs_j.clone().detach().double())
  kernel = NUTS(calibrated_model, jit_compile=True, init_strategy=init_to_value(values=init_vals), ignore_jit_warnings=True, max_tree_depth=9)
  posterior = MCMC(kernel, num_samples=2000, warmup_steps=200, num_chains=1)
  posterior.run(data_j)
  hmc_samples = {k: v.detach().cpu().numpy() for k, v in posterior.get_samples().items()}
  T = hmc_samples['T']
  Amp = hmc_samples['amp'] # Get posterior samples for amp
  var = hmc_samples['var'] # Get posterior samples for var
  gamma1_ = hmc_samples['gamma1'] # Get posterior samples for gamma1
  var = hmc_samples['var'] # Get posterior samples for var
  F = F_np_calibrated(x_esr_new.values.flatten(), Amp, gamma1_, T)
  qs = mquantiles(F.T, [0.025, 0.975], axis=0)
  F_mean = F.mean(axis = 1)
  idx.append(j)
  amp_.append(Amp.mean())  
  gamma1_vals.append(gamma1_.mean())
  temp_.append(T.mean())
  temp_var.append(T.var())
  gamma1_var.append(gamma1_.var())
  amp_var.append(Amp.var())
  T_ci = np.quantile(T, [0.025, 0.975])
  temp_ci_low.append(T_ci[0])
  temp_ci_high.append(T_ci[1])
  print('#################')
  print(f'experimental temperature: {temps_j.item():.2f} K, inferred temperature: {T.mean():.2f} K')
  plt.fill_between(x_esr_new.values.flatten(), qs[0], qs[1], alpha=0.7, color="#7A68A6");
  plt.plot(x_esr_new, F_mean)
  plt.plot(x_obs_j, y_obs_j, 'ro'); # plotting the data for this slice
  plt.xlabel('frequency axis')
  plt.title('Posterior distribution for the function given distributions for all parameters');plt.show()  
  print('#################')
# Out:
# 0
# Sample: 100%|██████████| 2200/2200 [01:05, 33.50it/s, step size=8.44e-01, acc. prob=0.893]
# #################
# experimental temperature: 25.00 K, inferred temperature: 292.90 K
# #################
# 1
# Warmup:   4%|▍         | 91/2200 [00:13,  7.66it/s, step size=1.57e-01, acc. prob=0.788]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 27
#      25 kernel = NUTS(calibrated_model, jit_compile=True, init_strategy=init_to_value(values=init_vals), ignore_jit_warnings=True, max_tree_depth=9)
#      26 posterior = MCMC(kernel, num_samples=2000, warmup_steps=200, num_chains=1)
# ---> 27 posterior.run(data_j)
#      28 hmc_samples = {k: v.detach().cpu().numpy() for k, v in posterior.get_samples().items()}
#      29 T = hmc_samples['T']
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\poutine\messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\infer\mcmc\api.py:565, in MCMC.run(self, *args, **kwargs)
#     556 with optional(
#     557     pyro.validation_enabled(not self.disable_validation),
#     558     self.disable_validation is not None,
#    (...)    562     # This also resolves "RuntimeError: Cowardly refusing to serialize non-leaf tensor which
#     563     # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#     564     args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
# --> 565     for x, chain_id in self.sampler.run(*args, **kwargs):
#     566         if num_samples[chain_id] == 0:
#     567             num_samples[chain_id] += 1
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\infer\mcmc\api.py:225, in _UnarySampler.run(self, *args, **kwargs)
#     223 logger = initialize_logger(logger, "", progress_bar)
#     224 hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
# --> 225 for sample in _gen_samples(
#     226     self.kernel,
#     227     self.warmup_steps,
#     228     self.num_samples,
#     229     hook_w_logging,
#     230     i if self.num_chains > 1 else None,
#     231     *args,
#     232     **kwargs
#     233 ):
#     234     yield sample, i  # sample, chain_id
#     235 self.kernel.cleanup()
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\infer\mcmc\api.py:152, in _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs)
#     150 yield {name: params[name].shape for name in save_params}
#     151 for i in range(warmup_steps):
# --> 152     params = kernel.sample(params)
#     153     hook(
#     154         kernel,
#     155         params,
#     156         "Warmup [{}]".format(chain_id) if chain_id is not None else "Warmup",
#     157         i,
#     158     )
#     159 for i in range(num_samples):
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\infer\mcmc\nuts.py:452, in NUTS.sample(self, params)
#     450     z_right_grads = new_tree.z_right_grads
#     451 else:  # go the the left, start from the left leaf of current tree
# --> 452     new_tree = self._build_tree(
#     453         z_left,
#     454         r_left,
#     455         z_left_grads,
#     456         log_slice,
#     457         direction,
#     458         tree_depth,
#     459         energy_current,
#     460     )
#     461     z_left = new_tree.z_left
#     462     r_left = new_tree.r_left
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\infer\mcmc\nuts.py:281, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     279     r = half_tree.r_left
#     280     z_grads = half_tree.z_left_grads
# --> 281 other_half_tree = self._build_tree(
#     282     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     283 )
#     285 if self.use_multinomial_sampling:
#     286     tree_weight = _logaddexp(half_tree.weight, other_half_tree.weight)
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\infer\mcmc\nuts.py:259, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     254     return self._build_basetree(
#     255         z, r, z_grads, log_slice, direction, energy_current
#     256     )
#     258 # build the first half of tree
# --> 259 half_tree = self._build_tree(
#     260     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     261 )
#     262 z_proposal = half_tree.z_proposal
#     263 z_proposal_pe = half_tree.z_proposal_pe
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\infer\mcmc\nuts.py:259, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     254     return self._build_basetree(
#     255         z, r, z_grads, log_slice, direction, energy_current
#     256     )
#     258 # build the first half of tree
# --> 259 half_tree = self._build_tree(
#     260     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     261 )
#     262 z_proposal = half_tree.z_proposal
#     263 z_proposal_pe = half_tree.z_proposal_pe
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\infer\mcmc\nuts.py:281, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     279     r = half_tree.r_left
#     280     z_grads = half_tree.z_left_grads
# --> 281 other_half_tree = self._build_tree(
#     282     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     283 )
#     285 if self.use_multinomial_sampling:
#     286     tree_weight = _logaddexp(half_tree.weight, other_half_tree.weight)
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\infer\mcmc\nuts.py:254, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     250 def _build_tree(
#     251     self, z, r, z_grads, log_slice, direction, tree_depth, energy_current
#     252 ):
#     253     if tree_depth == 0:
# --> 254         return self._build_basetree(
#     255             z, r, z_grads, log_slice, direction, energy_current
#     256         )
#     258     # build the first half of tree
#     259     half_tree = self._build_tree(
#     260         z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     261     )
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\infer\mcmc\nuts.py:199, in NUTS._build_basetree(self, z, r, z_grads, log_slice, direction, energy_current)
#     197 def _build_basetree(self, z, r, z_grads, log_slice, direction, energy_current):
#     198     step_size = self.step_size if direction == 1 else -self.step_size
# --> 199     z_new, r_new, z_grads, potential_energy = velocity_verlet(
#     200         z,
#     201         r,
#     202         self.potential_fn,
#     203         self.mass_matrix_adapter.kinetic_grad,
#     204         step_size,
#     205         z_grads=z_grads,
#     206     )
#     207     r_new_unscaled = self.mass_matrix_adapter.unscale(r_new)
#     208     energy_new = potential_energy + self._kinetic_energy(r_new_unscaled)
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\ops\integrator.py:39, in velocity_verlet(z, r, potential_fn, kinetic_grad, step_size, num_steps, z_grads)
#      37 r_next = r.copy()
#      38 for _ in range(num_steps):
# ---> 39     z_next, r_next, z_grads, potential_energy = _single_step_verlet(
#      40         z_next, r_next, potential_fn, kinetic_grad, step_size, z_grads
#      41     )
#      42 return z_next, r_next, z_grads, potential_energy
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\ops\integrator.py:61, in _single_step_verlet(z, r, potential_fn, kinetic_grad, step_size, z_grads)
#      58 for site_name in z:
#      59     z[site_name] = z[site_name] + step_size * r_grads[site_name]  # z(n+1)
# ---> 61 z_grads, potential_energy = potential_grad(potential_fn, z)
#      62 for site_name in r:
#      63     r[site_name] = r[site_name] + 0.5 * step_size * (-z_grads[site_name])  # r(n+1)
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\pyro\ops\integrator.py:91, in potential_grad(potential_fn, z)
#      89     else:
#      90         raise e
# ---> 91 grads = grad(potential_energy, z_nodes)
#      92 for node in z_nodes:
#      93     node.requires_grad_(False)
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\torch\autograd\__init__.py:496, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     492     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     493         grad_outputs_
#     494     )
#     495 else:
# --> 496     result = _engine_run_backward(
#     497         outputs,
#     498         grad_outputs_,
#     499         retain_graph,
#     500         create_graph,
#     501         inputs,
#     502         allow_unused,
#     503         accumulate_grad=False,
#     504     )
#     505 if materialize_grads:
#     506     if any(
#     507         result[i] is None and not is_tensor_like(inputs[i])
#     508         for i in range(len(inputs))
#     509     ):
#
# File c:\working_dir\nv_odmr\venv_odmr\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
temperature = np.asarray(temp_)
plt.plot(temperature, 'o-')
plt.plot(np.asarray(temps[:]), 'ro--')
plt.plot(np.asarray(temps_whole[:]), 'rx--')

plt.legend([ 'Predicted Temperature (Training)', 'Measured Temperature',])
